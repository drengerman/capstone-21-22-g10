# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import glob
import cv2
import statsmodels.api as sm
from statsmodels.graphics import tsaplots
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Dec 2 Bare Ice Test 1 GHz Scan Results 


# This is a folder with all the csv files you want in it
directory = "/content/drive/MyDrive/SERF CSV Files/Dec 2 Bare Ice Test/Lineset"

csv_files = sorted(glob.glob(os.path.join(directory, "*.csv"))) # This line gets a sorted list of all csv files in the directory
dfs = [] # this will store the dataframes
for f in csv_files:
  dfs.append(pd.read_csv(f, skiprows=3, header=None).iloc[:,2:]) # read the csv using pd.read_csv and append it to the list of dataframes

#Different Style of Parser which will take n+1th and n+1th on the i+1th iteration
start_val = 0
end_val = 10
jj = 0 # This is the starting value of the dataframe of dataframes
i = start_val
T = end_val - 1
my_vals = []
inter_val = []
counter_1 = 0
stopper = False 

for jj in range(len(dfs)):
  inter_val = []
  for ii in range(len(dfs[jj].columns)):
    if T <= (len(dfs[jj].columns)-1):
      inter_val.append(1-dfs[jj].corr().iloc[i,T])
      i = i+1
      T = T+1
    elif T == len(dfs[jj].columns):
      i = start_val
      T = end_val - 1 
  plt.plot(inter_val, label='Line {}'.format(jj+1))
  my_vals.append(inter_val)    
plt.legend()

# %%
#Dec 4, 2021  1 GHz Ice Test @ 4.65cm Ice Thicknes (2 Pigs) Scan Results 


# This is a folder with all the csv files you want in it
directory = "/content/drive/MyDrive/SERF CSV Files/Dec 4 Ice Tests (2 Pigs)/Lineset"

csv_files = sorted(glob.glob(os.path.join(directory, "*.csv"))) # This line gets a sorted list of all csv files in the directory
dfs = [] # this will store the dataframes
for f in csv_files:
  dfs.append(pd.read_csv(f, skiprows=3, header=None).iloc[:,2:]) # read the csv using pd.read_csv and append it to the list of dataframes

#Different Style of Parser which will take n+1th and n+1th on the i+1th iteration
start_val = 0
end_val = 10
jj = 0 # This is the starting value of the dataframe of dataframes
i = start_val
T = end_val - 1
my_vals = []
inter_val = []
counter_1 = 0
stopper = False 

for jj in range(len(dfs)):
  inter_val = []
  for ii in range(len(dfs[jj].columns)):
    if T <= (len(dfs[jj].columns)-1):
      inter_val.append(1-dfs[jj].corr().iloc[i,T])
      i = i+1
      T = T+1
    elif T == len(dfs[jj].columns):
      i = start_val
      T = end_val - 1   
  plt.plot(inter_val, label='Line {}'.format(jj+1))
  my_vals.append(inter_val)    
plt.legend()

# %%
#Dec 8 1 GHz Ice Test @ 18.5cm Ice Thicknes (2 Pigs) Scan Results 


# This is a folder with all the csv files you want in it
directory = "/content/drive/MyDrive/SERF CSV Files/Dec 8 Ice Test (2 Pigs)/Lineset"

csv_files = sorted(glob.glob(os.path.join(directory, "*.csv"))) # This line gets a sorted list of all csv files in the directory
dfs = [] # this will store the dataframes
for f in csv_files:
  dfs.append(pd.read_csv(f, skiprows=3, header=None).iloc[:,2:]) # read the csv using pd.read_csv and append it to the list of dataframes

#Different Style of Parser which will take n+1th and n+1th on the i+1th iteration
start_val = 0
end_val = 10
jj = 0 # This is the starting value of the dataframe of dataframes
i = start_val
T = end_val - 1
my_vals = []
inter_val = []
counter_1 = 0
stopper = False 

for jj in range(len(dfs)):
  inter_val = []
  for ii in range(len(dfs[jj].columns)):
    if T <= (len(dfs[jj].columns)-1):
      inter_val.append(1-dfs[jj].corr().iloc[i,T])
      i = i+1
      T = T+1
    elif T == len(dfs[jj].columns):
      i = start_val
      T = end_val - 1 
  plt.plot(inter_val, label='Line {}'.format(jj+1))
  my_vals.append(inter_val)    
plt.legend()

# %%
#Dec 13 1 GHz Ice Test @ 26.5cm Ice Thicknes (2 Pigs) Scan Results 


# This is a folder with all the csv files you want in it
directory = "/content/drive/MyDrive/SERF CSV Files/Dec 13th Ice Test (2 Pigs)/Lineset"

csv_files = sorted(glob.glob(os.path.join(directory, "*.csv"))) # This line gets a sorted list of all csv files in the directory
dfs = [] # this will store the dataframes
for f in csv_files:
  dfs.append(pd.read_csv(f, skiprows=3, header=None).iloc[:,2:]) # read the csv using pd.read_csv and append it to the list of dataframes

#Different Style of Parser which will take n+1th and n+1th on the i+1th iteration
start_val = 0
end_val = 10
jj = 0 # This is the starting value of the dataframe of dataframes
i = start_val
T = end_val - 1
my_vals = []
inter_val = []
counter_1 = 0
stopper = False 

for jj in range(len(dfs)):
  inter_val = []
  for ii in range(len(dfs[jj].columns)):
    if T <= (len(dfs[jj].columns)-1):
      inter_val.append(1-dfs[jj].corr().iloc[i,T])
      i = i+1
      T = T+1
    elif T == len(dfs[jj].columns):
      i = start_val
      T = end_val - 1  
  plt.plot(inter_val, label='Line {}'.format(jj+1))
  my_vals.append(inter_val)    
plt.legend()

# %%
#Dec 15 1 GHz Ice Test @ 26 cm Ice Thicknes (2 Pigs) Scan Results 


# This is a folder with all the csv files you want in it
directory = "/content/drive/MyDrive/SERF CSV Files/Dec 15th Ice Test (2 Pigs)/Lineset"

csv_files = sorted(glob.glob(os.path.join(directory, "*.csv"))) # This line gets a sorted list of all csv files in the directory
dfs = [] # this will store the dataframes
for f in csv_files:
  dfs.append(pd.read_csv(f, skiprows=3, header=None).iloc[:,2:]) # read the csv using pd.read_csv and append it to the list of dataframes

#Different Style of Parser which will take n+1th and n+1th on the i+1th iteration
start_val = 0
end_val = 10
jj = 0 # This is the starting value of the dataframe of dataframes
i = start_val
T = end_val - 1
my_vals = []
inter_val = []
counter_1 = 0
stopper = False 

for jj in range(len(dfs)):
  inter_val = []
  for ii in range(len(dfs[jj].columns)):
    if T <= (len(dfs[jj].columns)-1):
      inter_val.append(1-dfs[jj].corr().iloc[i,T])
      i = i+1
      T = T+1
    elif T == len(dfs[jj].columns):
      i = start_val
      T = end_val - 1  
  plt.plot(inter_val, label='Line {}'.format(jj+1))
  my_vals.append(inter_val)    
plt.legend()

# %%
#Dec 23 1 GHz Ice Test (3 Pigs) Scan Results 


# This is a folder with all the csv files you want in it
directory = "/content/drive/MyDrive/SERF CSV Files/Dec 23rd 1GHz  Ice Test (3 Pigs)/Lineset"

csv_files = sorted(glob.glob(os.path.join(directory, "*.csv"))) # This line gets a sorted list of all csv files in the directory
dfs = [] # this will store the dataframes
for f in csv_files:
  dfs.append(pd.read_csv(f, skiprows=3, header=None).iloc[:,2:]) # read the csv using pd.read_csv and append it to the list of dataframes

#Different Style of Parser which will take n+1th and n+1th on the i+1th iteration
start_val = 0
end_val = 10
jj = 0 # This is the starting value of the dataframe of dataframes
i = start_val
T = end_val - 1
my_vals = []
inter_val = []
counter_1 = 0
stopper = False 

for jj in range(len(dfs)):
  inter_val = []
  for ii in range(len(dfs[jj].columns)):
    if T <= (len(dfs[jj].columns)-1):
      inter_val.append(1-dfs[jj].corr().iloc[i,T])
      i = i+1
      T = T+1
    elif T == len(dfs[jj].columns):
      i = start_val
      T = end_val - 1 
  plt.plot(inter_val, label='Line {}'.format(jj+1))
  my_vals.append(inter_val)    
plt.legend()

# %%
#Dec 23 500 MHz Ice Test (3 Pigs) Scan Results 


# This is a folder with all the csv files you want in it
directory = "/content/drive/MyDrive/SERF CSV Files/Dec 23rd 500MHz Ice Test (3 Pigs)/Lineset"

csv_files = sorted(glob.glob(os.path.join(directory, "*.csv"))) # This line gets a sorted list of all csv files in the directory
dfs = [] # this will store the dataframes
for f in csv_files:
  dfs.append(pd.read_csv(f, skiprows=3, header=None).iloc[:,2:]) # read the csv using pd.read_csv and append it to the list of dataframes

#Different Style of Parser which will take n+1th and n+1th on the i+1th iteration
start_val = 0
end_val = 10
jj = 0 # This is the starting value of the dataframe of dataframes
i = start_val
T = end_val - 1
my_vals = []
inter_val = []
counter_1 = 0
stopper = False 

for jj in range(len(dfs)):
  inter_val = []
  for ii in range(len(dfs[jj].columns)):
    if T <= (len(dfs[jj].columns)-1):
      inter_val.append(1-dfs[jj].corr().iloc[i,T])
      i = i+1
      T = T+1
    elif T == len(dfs[jj].columns):
      i = start_val
      T = end_val - 1  
  plt.plot(inter_val, label='Line {}'.format(jj+1))
  my_vals.append(inter_val)    
plt.legend()

# %%
#Jan 13 2022 1 GHz Ice Test (3 Pigs) Scan Results 


# This is a folder with all the csv files you want in it
directory = "/content/drive/MyDrive/SERF CSV Files/Jan 13th 1GHz Ice Test (3 Pigs)/CSV Scans of Jan 13 1GHz/Lineset"

csv_files = sorted(glob.glob(os.path.join(directory, "*.csv"))) # This line gets a sorted list of all csv files in the directory
dfs = [] # this will store the dataframes
for f in csv_files:
  dfs.append(pd.read_csv(f, skiprows=3, header=None).iloc[:,2:]) # read the csv using pd.read_csv and append it to the list of dataframes

#Different Style of Parser which will take n+1th and n+1th on the i+1th iteration
start_val = 0
end_val = 10
jj = 0 # This is the starting value of the dataframe of dataframes
i = start_val
T = end_val - 1
my_vals = []
inter_val = []
counter_1 = 0
stopper = False 

for jj in range(len(dfs)):
  inter_val = []
  for ii in range(len(dfs[jj].columns)):
    if T <= (len(dfs[jj].columns)-1):
      inter_val.append(1-dfs[jj].corr().iloc[i,T])
      i = i+1
      T = T+1
    elif T == len(dfs[jj].columns):
      i = start_val
      T = end_val - 1 
  plt.plot(inter_val, label='Line {}'.format(jj+1))
  my_vals.append(inter_val)    
plt.legend()

# %%
#Jan 13 2022 500 MHz Ice Test (3 Pigs) Scan Results 


# This is a folder with all the csv files you want in it
directory = "/content/drive/MyDrive/SERF CSV Files/Jan 13th 500MHz Ice Test (3 Pigs)/Jan 13 CSV Files for 500HZz/Lineset"

csv_files = sorted(glob.glob(os.path.join(directory, "*.csv"))) # This line gets a sorted list of all csv files in the directory
dfs = [] # this will store the dataframes
for f in csv_files:
  dfs.append(pd.read_csv(f, skiprows=3, header=None).iloc[:,2:]) # read the csv using pd.read_csv and append it to the list of dataframes

#Different Style of Parser which will take n+1th and n+1th on the i+1th iteration
start_val = 0
end_val = 10
jj = 0 # This is the starting value of the dataframe of dataframes
i = start_val
T = end_val - 1
my_vals = []
inter_val = []
counter_1 = 0
stopper = False 

for jj in range(len(dfs)):
  inter_val = []
  for ii in range(len(dfs[jj].columns)):
    if T <= (len(dfs[jj].columns)-1):
      inter_val.append(1-dfs[jj].corr().iloc[i,T])
      i = i+1
      T = T+1
    elif T == len(dfs[jj].columns):
      i = start_val
      T = end_val - 1  
  plt.plot(inter_val, label='Line {}'.format(jj+1))
  my_vals.append(inter_val)    
plt.legend()

# %%
#Jan 28 2022 Long 1 GHz Ice Test (3 Pigs) Scan Results 


# This is a folder with all the csv files you want in it
directory = "/content/drive/MyDrive/SERF CSV Files/Jan 28th Long 1 GHz (3 Pigs)/Lineset"

csv_files = sorted(glob.glob(os.path.join(directory, "*.csv"))) # This line gets a sorted list of all csv files in the directory
dfs = [] # this will store the dataframes
for f in csv_files:
  dfs.append(pd.read_csv(f, skiprows=3, header=None).iloc[:,2:]) # read the csv using pd.read_csv and append it to the list of dataframes

#Different Style of Parser which will take n+1th and n+1th on the i+1th iteration
start_val = 0
end_val = 10
jj = 0 # This is the starting value of the dataframe of dataframes
i = start_val
T = end_val - 1
my_vals = []
inter_val = []
counter_1 = 0
stopper = False 

for jj in range(len(dfs)):
  inter_val = []
  for ii in range(len(dfs[jj].columns)):
    if T <= (len(dfs[jj].columns)-1):
      inter_val.append(1-dfs[jj].corr().iloc[i,T])
      i = i+1
      T = T+1
    elif T == len(dfs[jj].columns):
      i = start_val
      T = end_val - 1  
  plt.plot(inter_val, label='Line {}'.format(jj+1))
  my_vals.append(inter_val)    
plt.legend()

# %%
#Jan 28 2022 Long 500 MHz Ice Test (3 Pigs) Scan Results 


# This is a folder with all the csv files you want in it
directory = "/content/drive/MyDrive/SERF CSV Files/Jan 28th Long 500 Mhz (3 Pigs)/Lineset"

csv_files = sorted(glob.glob(os.path.join(directory, "*.csv"))) # This line gets a sorted list of all csv files in the directory
dfs = [] # this will store the dataframes
for f in csv_files:
  dfs.append(pd.read_csv(f, skiprows=3, header=None).iloc[:,2:]) # read the csv using pd.read_csv and append it to the list of dataframes

#Different Style of Parser which will take n+1th and n+1th on the i+1th iteration
start_val = 0
end_val = 10
jj = 0 # This is the starting value of the dataframe of dataframes
i = start_val
T = end_val - 1
my_vals = []
inter_val = []
counter_1 = 0
stopper = False 

for jj in range(len(dfs)):
  inter_val = []
  for ii in range(len(dfs[jj].columns)):
    if T <= (len(dfs[jj].columns)-1):
      inter_val.append(1-dfs[jj].corr().iloc[i,T])
      i = i+1
      T = T+1
    elif T == len(dfs[jj].columns):
      i = start_val
      T = end_val - 1  
  plt.plot(inter_val, label='Line {}'.format(jj+1))
  my_vals.append(inter_val)    
plt.legend()

# %%
#Jan 28 2022 Long 500 MHz Ice Test (3 Pigs) Scan Results 


# This is a folder with all the csv files you want in it
directory = "/content/drive/MyDrive/SERF CSV Files/Jan 28th Long 500 Mhz (3 Pigs)/Lineset"

csv_files = sorted(glob.glob(os.path.join(directory, "*.csv"))) # This line gets a sorted list of all csv files in the directory
dfs = [] # this will store the dataframes
for f in csv_files:
  dfs.append(pd.read_csv(f, skiprows=3, header=None).iloc[:,2:]) # read the csv using pd.read_csv and append it to the list of dataframes

#Different Style of Parser which will take n+1th and n+1th on the i+1th iteration
start_val = 0
end_val = 10
jj = 0 # This is the starting value of the dataframe of dataframes
i = start_val
T = end_val - 1
my_vals = []
inter_val = []
counter_1 = 0
stopper = False 

for jj in range(len(dfs)):
  inter_val = []
  for ii in range(len(dfs[jj].columns)):
    if T <= (len(dfs[jj].columns)-1):
      inter_val.append(1-dfs[jj].corr().iloc[i,T])
      i = i+1
      T = T+1
    elif T == len(dfs[jj].columns):
      i = start_val
      T = end_val - 1  
  plt.plot(inter_val, label='Line {}'.format(jj+1))
  my_vals.append(inter_val)    
plt.legend()

# %%
#Jan 28 2022 Long with SNOW 1 GHz Ice Test (3 Pigs) Scan Results 


# This is a folder with all the csv files you want in it
directory = "/content/drive/MyDrive/SERF CSV Files/Jan 28th Long Snow 1 GHz/Lineset"

csv_files = sorted(glob.glob(os.path.join(directory, "*.csv"))) # This line gets a sorted list of all csv files in the directory
dfs = [] # this will store the dataframes
for f in csv_files:
  dfs.append(pd.read_csv(f, skiprows=3, header=None).iloc[:,2:]) # read the csv using pd.read_csv and append it to the list of dataframes

#Different Style of Parser which will take n+1th and n+1th on the i+1th iteration
start_val = 0
end_val = 10
jj = 0 # This is the starting value of the dataframe of dataframes
i = start_val
T = end_val - 1
my_vals = []
inter_val = []
counter_1 = 0
stopper = False 

for jj in range(len(dfs)):
  inter_val = []
  for ii in range(len(dfs[jj].columns)):
    if T <= (len(dfs[jj].columns)-1):
      inter_val.append(1-dfs[jj].corr().iloc[i,T])
      i = i+1
      T = T+1
    elif T == len(dfs[jj].columns):
      i = start_val
      T = end_val - 1  
  plt.plot(inter_val, label='Line {}'.format(jj+1))
  my_vals.append(inter_val)    
plt.legend()

# %%
#Jan 28 2022 Long with SNOW 500 MHz Ice Test (3 Pigs) Scan Results 


# This is a folder with all the csv files you want in it
directory = "/content/drive/MyDrive/SERF CSV Files/Jan 28th Long Snow 500 MHz/Lineset"

csv_files = sorted(glob.glob(os.path.join(directory, "*.csv"))) # This line gets a sorted list of all csv files in the directory
dfs = [] # this will store the dataframes
for f in csv_files:
  dfs.append(pd.read_csv(f, skiprows=3, header=None).iloc[:,2:]) # read the csv using pd.read_csv and append it to the list of dataframes

#Different Style of Parser which will take n+1th and n+1th on the i+1th iteration
start_val = 0
end_val = 10
jj = 0 # This is the starting value of the dataframe of dataframes
i = start_val
T = end_val - 1
my_vals = []
inter_val = []
counter_1 = 0
stopper = False 

for jj in range(len(dfs)):
  inter_val = []
  for ii in range(len(dfs[jj].columns)):
    if T <= (len(dfs[jj].columns)-1):
      inter_val.append(1-dfs[jj].corr().iloc[i,T])
      i = i+1
      T = T+1
    elif T == len(dfs[jj].columns):
      i = start_val
      T = end_val - 1  
  plt.plot(inter_val, label='Line {}'.format(jj+1))
  my_vals.append(inter_val)    
plt.legend()

# %%
#Jan 28 2022 Side 1 GHz Ice Test (3 Pigs) Scan Results 


# This is a folder with all the csv files you want in it
directory = "/content/drive/MyDrive/SERF CSV Files/Jan 28th Side 1 GHz/Lineset"

csv_files = sorted(glob.glob(os.path.join(directory, "*.csv"))) # This line gets a sorted list of all csv files in the directory
dfs = [] # this will store the dataframes
for f in csv_files:
  dfs.append(pd.read_csv(f, skiprows=3, header=None).iloc[:,2:]) # read the csv using pd.read_csv and append it to the list of dataframes

#Different Style of Parser which will take n+1th and n+1th on the i+1th iteration
start_val = 0
end_val = 10
jj = 0 # This is the starting value of the dataframe of dataframes
i = start_val
T = end_val - 1
my_vals = []
inter_val = []
counter_1 = 0
stopper = False 

for jj in range(len(dfs)):
  inter_val = []
  for ii in range(len(dfs[jj].columns)):
    if T <= (len(dfs[jj].columns)-1):
      inter_val.append(1-dfs[jj].corr().iloc[i,T])
      i = i+1
      T = T+1
    elif T == len(dfs[jj].columns):
      i = start_val
      T = end_val - 1  
  plt.plot(inter_val, label='Line {}'.format(jj+1))
  my_vals.append(inter_val)    
plt.legend()

# %%
#Jan 28 2022 Side 500 MHz Ice Test (3 Pigs) Scan Results 


# This is a folder with all the csv files you want in it
directory = "/content/drive/MyDrive/SERF CSV Files/Jan 28th Side 500 MHz/Lineset"

csv_files = sorted(glob.glob(os.path.join(directory, "*.csv"))) # This line gets a sorted list of all csv files in the directory
dfs = [] # this will store the dataframes
for f in csv_files:
  dfs.append(pd.read_csv(f, skiprows=3, header=None).iloc[:,2:]) # read the csv using pd.read_csv and append it to the list of dataframes

#Different Style of Parser which will take n+1th and n+1th on the i+1th iteration
start_val = 0
end_val = 10
jj = 0 # This is the starting value of the dataframe of dataframes
i = start_val
T = end_val - 1
my_vals = []
inter_val = []
counter_1 = 0
stopper = False 

for jj in range(len(dfs)):
  inter_val = []
  for ii in range(len(dfs[jj].columns)):
    if T <= (len(dfs[jj].columns)-1):
      inter_val.append(1-dfs[jj].corr().iloc[i,T])
      i = i+1
      T = T+1
    elif T == len(dfs[jj].columns):
      i = start_val
      T = end_val - 1  
  plt.plot(inter_val, label='Line {}'.format(jj+1))
  my_vals.append(inter_val)    
plt.legend()
